# %% [markdown]
# Tsunami Study 1750-2023

# %% [markdown]
# Import the necessary libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print('Libraries imported successfully')
# Out:
# Libraries imported successfully

# %% [markdown]
# Create a pandas data frame from TSV file

# %%
file=r'Tsunami(1750-present).tsv'
df=pd.read_csv(file, sep='\t')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2393 entries, 0 to 2392
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          0 non-null      float64
#  1   Id                                  2392 non-null   float64
#  2   Year                                2392 non-null   float64
#  3   Mo                                  2330 non-null   float64
#  4   Dy                                  2258 non-null   float64
#  5   Hr                                  1437 non-null   float64
#  6   Mn                                  1373 non-null   float64
#  7   Sec                                 982 non-null    float64
#  8   Tsunami Event Validity              2392 non-null   float64
#  9   Tsunami Cause Code                  2389 non-null   float64
#  10  Earthquake Magnitude                1400 non-null   float64
#  11  Focal Depth (km)                    997 non-null    float64
#  12  Vol                                 141 non-null    float64
#  13  More Info                           0 non-null      float64
#  14  Deposits                            2392 non-null   float64
#  15  Country                             2391 non-null   object
#  16  Area                                317 non-null    object
#  17  Region                              2391 non-null   float64
#  18  Location Name                       2390 non-null   object
#  19  Latitude                            2093 non-null   float64
#  20  Longitude                           2093 non-null   float64
#  21  Maximum Water Height (m)            1206 non-null   float64
#  22  Number of Runups                    2392 non-null   float64
#  23  Tsunami Magnitude (Abe)             1 non-null      float64
#  24  Tsunami Magnitude (Iida)            622 non-null    float64
#  25  Tsunami Intensity                   974 non-null    float64
#  26  Warn Status                         70 non-null     float64
#  27  Deaths                              225 non-null    float64
#  28  Death Description                   271 non-null    float64
#  29  Missing                             4 non-null      float64
#  30  Missing Description                 5 non-null      float64
#  31  Injuries                            77 non-null     float64
#  32  Injuries Description                89 non-null     float64
#  33  Damage ($Mil)                       47 non-null     float64
#  34  Damage Description                  517 non-null    float64
#  35  Houses Destroyed                    83 non-null     float64
#  36  Houses Destroyed Description        227 non-null    float64
#  37  Houses Damaged                      17 non-null     float64
#  38  Houses Damaged Description          63 non-null     float64
#  39  Total Deaths                        561 non-null    float64
#  40  Total Death Description             640 non-null    float64
#  41  Total Missing                       11 non-null     float64
#  42  Total Missing Description           13 non-null     float64
#  43  Total Injuries                      305 non-null    float64
#  44  Total Injuries Description          357 non-null    float64
#  45  Total Damage ($Mil)                 157 non-null    float64
#  46  Total Damage Description            1061 non-null   float64
#  47  Total Houses Destroyed              228 non-null    float64
#  48  Total Houses Destroyed Description  573 non-null    float64
#  49  Total Houses Damaged                96 non-null     float64
#  50  Total Houses Damaged Description    256 non-null    float64
# dtypes: float64(48), object(3)
# memory usage: 953.6+ KB

# %% [markdown]
# Insights
#
# Size and Structure: The DataFrame contains 2393 entries, each representing a record, and has 51 columns. Each column represents a different attribute or feature of the data.
#
# Missing Data: There's a significant amount of missing data in several columns. For example, columns like 'Hr', 'Mn', 'Sec', 'Earthquake Magnitude', 'Focal Depth (km)', and 'Vol' have a large number of null values. This suggests that for many records, specific details like the exact time of the event or earthquake-related information are not available.
#
# Data Types: The majority of the columns are of float64 type, indicating numerical data. There are also a few object-type columns ('Country', 'Area', 'Location Name'), which are likely categorical or textual data.
#
# Specific Columns with High Nullity:
#
# 'Unnamed: 0' and 'More Info' columns have all null values, which means these columns might not be useful for analysis.
# 'Focal Depth (km)' and 'Vol' have very few non-null entries, suggesting that these features are only relevant for a small subset of the data (possibly specific types of events).
#
# Geographical Information: The dataset includes geographical data, such as 'Country', 'Area', 'Region', 'Latitude', and 'Longitude'. However, 'Area' has a high number of null values, indicating that this specific geographical detail is often missing.
#
# Event Timing: The columns 'Year', 'Mo', 'Dy', 'Hr', 'Mn', and 'Sec' are intended to provide the exact timing of the events. However, as you move from 'Year' to 'Sec', the number of non-null entries decreases, suggesting that finer details of the timing (like hours, minutes, and seconds) are often not recorded.

# %% [markdown]
# View the first 5 rows

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Unnamed: 0      Id    Year    Mo    Dy  Hr  Mn  Sec  \
# 0         NaN     NaN     NaN   NaN   NaN NaN NaN  NaN
# 1         NaN  3688.0  1750.0  10.0   NaN NaN NaN  NaN
# 2         NaN  3165.0  1750.0  12.0  17.0 NaN NaN  NaN
# 3         NaN   433.0  1750.0   NaN   NaN NaN NaN  NaN
# 4         NaN   434.0  1750.0   NaN   NaN NaN NaN  NaN
#
#    Tsunami Event Validity  Tsunami Cause Code  Earthquake Magnitude  \
# 0                     NaN                 NaN                   NaN
# 1                     0.0                 1.0                   NaN
# 2                     2.0                 1.0                   NaN
# 3                     1.0                 1.0                   NaN
# 4                     1.0                 1.0                   NaN
#
#    Focal Depth (km)  Vol  More Info  Deposits          Country Area  Region  \
# 0               NaN  NaN        NaN       NaN              NaN  NaN     NaN
# 1               NaN  NaN        NaN       0.0         BULGARIA  NaN    50.0
# 2               NaN  NaN        NaN       0.0          CROATIA  NaN    50.0
# 3               NaN  NaN        NaN       0.0        VENEZUELA  NaN    74.0
# 4               NaN  NaN        NaN       0.0  MYANMAR (BURMA)  NaN    60.0
#
#            Location Name  Latitude  Longitude  Maximum Water Height (m)  \
# 0                    NaN       NaN        NaN                       NaN
# 1          MARITZA RIVER      42.1     24.800                       NaN
# 2                 RIJEKA      46.0     12.250                       NaN
# 3                 CUMANA      10.7    -64.100                       NaN
# 4  MYANMAR (BURMA) COAST      18.8     93.633                       NaN
#
#    Number of Runups  Tsunami Magnitude (Abe)  Tsunami Magnitude (Iida)  \
# 0               NaN                      NaN                       NaN
# 1               0.0                      NaN                       NaN
# 2               1.0                      NaN                       NaN
# 3               1.0                      NaN                       NaN
# 4               0.0                      NaN                       NaN
#
#    Tsunami Intensity  Warn Status  Deaths  Death Description  Missing  \
# 0                NaN          NaN     NaN                NaN      NaN
# 1                NaN          NaN     NaN                NaN      NaN
# 2                3.0          NaN     NaN                NaN      NaN
# 3                NaN          NaN     NaN                NaN      NaN
# 4                4.0          NaN     NaN                NaN      NaN
#
#    Missing Description  Injuries  Injuries Description  Damage ($Mil)  \
# 0                  NaN       NaN                   NaN            NaN
# 1                  NaN       NaN                   NaN            NaN
# 2                  NaN       NaN                   NaN            NaN
# 3                  NaN       NaN                   NaN            NaN
# 4                  NaN       NaN                   NaN            NaN
#
#    Damage Description  Houses Destroyed  Houses Destroyed Description  \
# 0                 NaN               NaN                           NaN
# 1                 NaN               NaN                           NaN
# 2                 NaN               NaN                           NaN
# 3                 NaN               NaN                           NaN
# 4                 NaN               NaN                           NaN
#
#    Houses Damaged  Houses Damaged Description  Total Deaths  \
# 0             NaN                         NaN           NaN
# 1             NaN                         NaN           NaN
# 2             NaN                         NaN           NaN
# 3             NaN                         NaN           NaN
# 4             NaN                         NaN           NaN
#
#    Total Death Description  Total Missing  Total Missing Description  \
# 0                      NaN            NaN                        NaN
# 1                      NaN            NaN                        NaN
# 2                      3.0            NaN                        NaN
# 3                      NaN            NaN                        NaN
# 4                      NaN            NaN                        NaN
#
#    Total Injuries  Total Injuries Description  Total Damage ($Mil)  \
# 0             NaN                         NaN                  NaN
# 1             NaN                         NaN                  NaN
# 2             NaN                         NaN                  NaN
# 3             NaN                         NaN                  NaN
# 4             NaN                         NaN                  NaN
#
#    Total Damage Description  Total Houses Destroyed  \
# 0                       NaN                     NaN
# 1                       3.0                     NaN
# 2                       3.0                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
#
#    Total Houses Destroyed Description  Total Houses Damaged  \
# 0                                 NaN                   NaN
# 1                                 3.0                   NaN
# 2                                 3.0                   NaN
# 3                                 NaN                   NaN
# 4                                 NaN                   NaN
#
#    Total Houses Damaged Description
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN

# %% [markdown]
# View the last 5 rows

# %%
df.tail()
# Out:
#       Unnamed: 0      Id    Year    Mo    Dy    Hr    Mn   Sec  \
# 2388         NaN  5890.0  2023.0  10.0   5.0   1.0  59.0  58.0
# 2389         NaN  5891.0  2023.0  10.0   8.0   NaN   NaN   NaN
# 2390         NaN  5902.0  2023.0  11.0  22.0   4.0  47.0  33.0
# 2391         NaN  5903.0  2023.0  12.0   2.0  14.0  37.0   3.0
# 2392         NaN  5904.0  2023.0  12.0   7.0  12.0  56.0  30.0
#
#       Tsunami Event Validity  Tsunami Cause Code  Earthquake Magnitude  \
# 2388                     4.0                 1.0                   6.1
# 2389                     4.0                 0.0                   NaN
# 2390                     4.0                 1.0                   6.7
# 2391                     4.0                 1.0                   7.6
# 2392                     4.0                 1.0                   7.1
#
#       Focal Depth (km)  Vol  More Info  Deposits      Country Area  Region  \
# 2388              10.0  NaN        NaN       0.0        JAPAN  NaN    85.0
# 2389               NaN  NaN        NaN       0.0        JAPAN  NaN    85.0
# 2390              22.0  NaN        NaN       0.0      VANUATU  NaN    82.0
# 2391              32.0  NaN        NaN       0.0  PHILIPPINES  NaN    84.0
# 2392              48.0  NaN        NaN       0.0      VANUATU  NaN    82.0
#
#            Location Name  Latitude  Longitude  Maximum Water Height (m)  \
# 2388  IZU ISLANDS, JAPAN    29.940    139.950                      0.30
# 2389  IZU ISLANDS, JAPAN    29.700    139.900                      0.30
# 2390     VANUATU ISLANDS   -14.985    167.983                      0.06
# 2391  E. MINDANAO ISLAND     8.527    126.449                      0.32
# 2392     VANUATU ISLANDS   -20.659    169.206                      0.08
#
#       Number of Runups  Tsunami Magnitude (Abe)  Tsunami Magnitude (Iida)  \
# 2388               1.0                      NaN                       NaN
# 2389              12.0                      NaN                       NaN
# 2390               1.0                      NaN                       NaN
# 2391              29.0                      NaN                       NaN
# 2392               3.0                      NaN                       NaN
#
#       Tsunami Intensity  Warn Status  Deaths  Death Description  Missing  \
# 2388                NaN          NaN     NaN                NaN      NaN
# 2389                NaN          NaN     NaN                NaN      NaN
# 2390                NaN          NaN     NaN                NaN      NaN
# 2391                NaN          NaN     NaN                NaN      NaN
# 2392                NaN          NaN     NaN                NaN      NaN
#
#       Missing Description  Injuries  Injuries Description  Damage ($Mil)  \
# 2388                  NaN       NaN                   NaN            NaN
# 2389                  NaN       NaN                   NaN            NaN
# 2390                  NaN       NaN                   NaN            NaN
# 2391                  NaN       NaN                   NaN            NaN
# 2392                  NaN       NaN                   NaN            NaN
#
#       Damage Description  Houses Destroyed  Houses Destroyed Description  \
# 2388                 NaN               NaN                           NaN
# 2389                 NaN               NaN                           NaN
# 2390                 NaN               NaN                           NaN
# 2391                 NaN               NaN                           NaN
# 2392                 NaN               NaN                           NaN
#
#       Houses Damaged  Houses Damaged Description  Total Deaths  \
# 2388             NaN                         NaN           NaN
# 2389             NaN                         NaN           NaN
# 2390             NaN                         NaN           NaN
# 2391             NaN                         NaN           3.0
# 2392             NaN                         NaN           NaN
#
#       Total Death Description  Total Missing  Total Missing Description  \
# 2388                      NaN            NaN                        NaN
# 2389                      NaN            NaN                        NaN
# 2390                      NaN            NaN                        NaN
# 2391                      1.0            NaN                        NaN
# 2392                      NaN            NaN                        NaN
#
#       Total Injuries  Total Injuries Description  Total Damage ($Mil)  \
# 2388             NaN                         NaN                  NaN
# 2389             NaN                         NaN                  NaN
# 2390             NaN                         NaN                  NaN
# 2391            67.0                         2.0                 4.46
# 2392             NaN                         NaN                  NaN
#
#       Total Damage Description  Total Houses Destroyed  \
# 2388                       NaN                     NaN
# 2389                       NaN                     NaN
# 2390                       NaN                     NaN
# 2391                       2.0                   406.0
# 2392                       NaN                     NaN
#
#       Total Houses Destroyed Description  Total Houses Damaged  \
# 2388                                 NaN                   NaN
# 2389                                 NaN                   NaN
# 2390                                 NaN                   NaN
# 2391                                 3.0                4888.0
# 2392                                 NaN                   NaN
#
#       Total Houses Damaged Description
# 2388                               NaN
# 2389                               NaN
# 2390                               NaN
# 2391                               4.0
# 2392                               NaN

# %% [markdown]
# From the head and tail methods we can see how the last 5 entries have far less NaN entries. This is likely due to better data acquisition techniques in more modern times.

# %% [markdown]
# Look at the uniquie values in each column

# %%
df.nunique()
# Out:
# Unnamed: 0                               0
# Id                                    2391
# Year                                   266
# Mo                                      12
# Dy                                      31
# Hr                                      24
# Mn                                      60
# Sec                                    381
# Tsunami Event Validity                   6
# Tsunami Cause Code                      12
# Earthquake Magnitude                    52
# Focal Depth (km)                       103
# Vol                                    141
# More Info                                0
# Deposits                                18
# Country                                112
# Area                                    32
# Region                                  23
# Location Name                          880
# Latitude                              1391
# Longitude                             1569
# Maximum Water Height (m)               240
# Number of Runups                       114
# Tsunami Magnitude (Abe)                  1
# Tsunami Magnitude (Iida)                63
# Tsunami Intensity                       32
# Warn Status                              5
# Deaths                                 102
# Death Description                        4
# Missing                                  4
# Missing Description                      3
# Injuries                                48
# Injuries Description                     4
# Damage ($Mil)                           41
# Damage Description                       4
# Houses Destroyed                        61
# Houses Destroyed Description             4
# Houses Damaged                          15
# Houses Damaged Description               4
# Total Deaths                           216
# Total Death Description                  4
# Total Missing                           10
# Total Missing Description                4
# Total Injuries                         166
# Total Injuries Description               4
# Total Damage ($Mil)                    115
# Total Damage Description                 4
# Total Houses Destroyed                 166
# Total Houses Destroyed Description       4
# Total Houses Damaged                    90
# Total Houses Damaged Description         4
# dtype: int64

# %% [markdown]
# Unique Identifiers:
# The 'Id' column has 2391 unique values, almost one per entry, suggesting it likely serves as a primary identifier for each record. he 'Unnamed: 0' and 'More Info' columns have 0 unique values, reinforcing the earlier observation that they may not be useful for analysis.
#
# Temporal Data:
# 'Year' has 266 unique values, indicating a wide range of years covered in the dataset.
# 'Mo', 'Dy', 'Hr', 'Mn', and 'Sec' have the maximum number of unique values possible for months, days, hours, minutes, and seconds, respectively. This suggests a detailed recording of event timings where available.
#
# Geographical and Event Specifics:
# The dataset covers events in 112 different countries and 880 unique location names, indicating a broad geographical scope.
# There are 23 unique regions and 32 areas, though the lower count of unique areas suggests less granularity or more missing data in this field.
#
# Tsunami Characteristics:
# The 'Earthquake Magnitude' and 'Focal Depth (km)' fields have 52 and 103 unique values, respectively, offering detailed insights into the seismic aspects of the events where applicable.
# 'Maximum Water Height (m)' has 240 unique values, providing a diverse range of tsunami heights.
#
# Impact Metrics:
# 'Deaths', 'Missing', 'Injuries', 'Damage ($Mil)', 'Houses Destroyed', and 'Houses Damaged' show varied numbers of unique values, indicating a wide range of impacts from different events.
#
# Descriptions and Intensity:
# Description columns (like 'Death Description', 'Damage Description') mostly have 4 unique values, likely representing categorical levels of impact.'Tsunami Intensity' has 32 unique values, offering a nuanced view of the severity of tsunami events.

# %% [markdown]
# We look at the % of missing values.

# %%
(df.isnull().sum()/(len(df)))*100
# Out:
# Unnamed: 0                            100.000000
# Id                                      0.041789
# Year                                    0.041789
# Mo                                      2.632679
# Dy                                      5.641454
# Hr                                     39.949854
# Mn                                     42.624321
# Sec                                    58.963644
# Tsunami Event Validity                  0.041789
# Tsunami Cause Code                      0.167154
# Earthquake Magnitude                   41.496030
# Focal Depth (km)                       58.336816
# Vol                                    94.107814
# More Info                             100.000000
# Deposits                                0.041789
# Country                                 0.083577
# Area                                   86.753030
# Region                                  0.083577
# Location Name                           0.125366
# Latitude                               12.536565
# Longitude                              12.536565
# Maximum Water Height (m)               49.603009
# Number of Runups                        0.041789
# Tsunami Magnitude (Abe)                99.958211
# Tsunami Magnitude (Iida)               74.007522
# Tsunami Intensity                      59.297952
# Warn Status                            97.074802
# Deaths                                 90.597576
# Death Description                      88.675303
# Missing                                99.832846
# Missing Description                    99.791057
# Injuries                               96.782282
# Injuries Description                   96.280819
# Damage ($Mil)                          98.035938
# Damage Description                     78.395320
# Houses Destroyed                       96.531550
# Houses Destroyed Description           90.513999
# Houses Damaged                         99.289595
# Houses Damaged Description             97.367321
# Total Deaths                           76.556623
# Total Death Description                73.255328
# Total Missing                          99.540326
# Total Missing Description              99.456749
# Total Injuries                         87.254492
# Total Injuries Description             85.081488
# Total Damage ($Mil)                    93.439198
# Total Damage Description               55.662349
# Total Houses Destroyed                 90.472211
# Total Houses Destroyed Description     76.055161
# Total Houses Damaged                   95.988299
# Total Houses Damaged Description       89.302131
# dtype: float64

# %% [markdown]
# By looking at the percntage of missing values we can start to make some assumptions about columns that could potentially be dropped. There are for example many colums with missing value percantages in the high ninties. Many of these will need to be dropped as there are not enough entries to draw any valuable insights from. Some however like "damage" and "deaths" will be interesting to look at to get an idea of the most devastating events.

# %% [markdown]
# Drop unnecessary columns

# %%
col_drop = [
'Unnamed: 0',
'Id',
'Hr',
'Mn',
'Sec',
'Vol',
'More Info',
'Tsunami Magnitude (Abe)',
'Warn Status',
'Missing',
'Missing Description',
'Injuries',
'Injuries Description',
'Houses Destroyed',
'Houses Destroyed Description',
'Houses Damaged',
'Houses Damaged Description',
'Total Deaths',
'Total Death Description',
'Total Missing',
'Total Missing Description',
'Total Injuries',
'Total Injuries Description',
'Total Damage ($Mil)',
'Total Damage Description',
'Total Houses Destroyed',
'Total Houses Destroyed Description',
'Total Houses Damaged',
'Total Houses Damaged Description'
]

df.drop(columns=col_drop, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2393 entries, 0 to 2392
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      2392 non-null   float64
#  1   Mo                        2330 non-null   float64
#  2   Dy                        2258 non-null   float64
#  3   Tsunami Event Validity    2392 non-null   float64
#  4   Tsunami Cause Code        2389 non-null   float64
#  5   Earthquake Magnitude      1400 non-null   float64
#  6   Focal Depth (km)          997 non-null    float64
#  7   Deposits                  2392 non-null   float64
#  8   Country                   2391 non-null   object
#  9   Area                      317 non-null    object
#  10  Region                    2391 non-null   float64
#  11  Location Name             2390 non-null   object
#  12  Latitude                  2093 non-null   float64
#  13  Longitude                 2093 non-null   float64
#  14  Maximum Water Height (m)  1206 non-null   float64
#  15  Number of Runups          2392 non-null   float64
#  16  Tsunami Magnitude (Iida)  622 non-null    float64
#  17  Tsunami Intensity         974 non-null    float64
#  18  Deaths                    225 non-null    float64
#  19  Death Description         271 non-null    float64
#  20  Damage ($Mil)             47 non-null     float64
#  21  Damage Description        517 non-null    float64
# dtypes: float64(19), object(3)
# memory usage: 411.4+ KB

# %% [markdown]
# An explanation for the dropped columns.
#
# Dropped Column Name	                Reason
# Unnamed: 0       	                Column contain no data
# Id	                                Does not provide any useful information for the analysis
# Hr	                                This degree of time information is not required
# Mn	                                This degree of time information is not required
# Sec	                                This degree of time information is not required
# Vol	                                Source data set provides a link to information about volcanic eruption pertaining to the tsunami event.
# More Info	                        Source data set provides a link with more information about the specific event.
# Tsunami Magnitude (Abe)	            99.9% missing values
# Warn Status	                        97% missing values
# Missing	                            99.8% missing values
# Missing Description	                99.8% missing values
# Injuries	                        96.8% missing values
# Injuries Description	            96.3% missing values
# Houses Destroyed	                96.5% missing values
# Houses Destroyed Description	    90.5% missing values
# Houses Damaged	                    99.3% missing values
# Houses Damaged Description	        97.4% missing values
# Total Death Description	            Total data columns will be dropped (Tsunami Only)
# Total Missing	                    Total data columns will be dropped (Tsunami Only)
# Total Missing Description	        Total data columns will be dropped (Tsunami Only)
# Total Injuries	                    Total data columns will be dropped (Tsunami Only)
# Total Injuries Description	        Total data columns will be dropped (Tsunami Only)
# Total Damage ($Mil)	                Total data columns will be dropped (Tsunami Only)
# Total Damage Description	        Total data columns will be dropped (Tsunami Only)
# Total Houses Destroyed	            Total data columns will be dropped (Tsunami Only)
# Total Houses Destroyed Description	Total data columns will be dropped (Tsunami Only)
# Total Houses Damaged	            Total data columns will be dropped (Tsunami Only)
# Total Houses Damaged Description	Total data columns will be dropped (Tsunami Only)

# %% [markdown]
# Next, we will correct the data types.

# %%
float_to_int = [
    "Year",
    "Mo",
    "Dy",
    "Deposits",
    "Number of Runups",
    "Deaths" 
]

df[float_to_int] = df[float_to_int].fillna(0).astype(int)

float_to_category = [
    "Tsunami Event Validity",
    "Tsunami Cause Code",
    "Region",
    "Death Description",
    "Damage Description"
]

df[float_to_category] = df[float_to_category].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2393 entries, 0 to 2392
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      2393 non-null   int32
#  1   Mo                        2393 non-null   int32
#  2   Dy                        2393 non-null   int32
#  3   Tsunami Event Validity    2392 non-null   category
#  4   Tsunami Cause Code        2389 non-null   category
#  5   Earthquake Magnitude      1400 non-null   float64
#  6   Focal Depth (km)          997 non-null    float64
#  7   Deposits                  2393 non-null   int32
#  8   Country                   2391 non-null   object
#  9   Area                      317 non-null    object
#  10  Region                    2391 non-null   category
#  11  Location Name             2390 non-null   object
#  12  Latitude                  2093 non-null   float64
#  13  Longitude                 2093 non-null   float64
#  14  Maximum Water Height (m)  1206 non-null   float64
#  15  Number of Runups          2393 non-null   int32
#  16  Tsunami Magnitude (Iida)  622 non-null    float64
#  17  Tsunami Intensity         974 non-null    float64
#  18  Deaths                    2393 non-null   int32
#  19  Death Description         271 non-null    category
#  20  Damage ($Mil)             47 non-null     float64
#  21  Damage Description        517 non-null    category
# dtypes: category(5), float64(8), int32(6), object(3)
# memory usage: 275.3+ KB

# %% [markdown]
# Tsunami Event Validity is described as follows:
#
# Valid values: -1 to 4
#
# Validity of the actual tsunami occurrence is indicated by a numerical rating of the reports of that event:
#
# -1	erroneous entry.
# 0	event that only caused a seiche or disturbance in an inland river/lake.
# 1	very doubtful tsunami.
# 2	questionable tsunami.
# 3	probable tsunami.
# 4	definite tsunami.
#
# We will only keep events with values 2 and higher.

# %%
keep=[2,3,4]

df = df[df['Tsunami Event Validity'].isin(keep)]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721 entries, 2 to 2392
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      1721 non-null   int32
#  1   Mo                        1721 non-null   int32
#  2   Dy                        1721 non-null   int32
#  3   Tsunami Event Validity    1721 non-null   category
#  4   Tsunami Cause Code        1721 non-null   category
#  5   Earthquake Magnitude      1187 non-null   float64
#  6   Focal Depth (km)          877 non-null    float64
#  7   Deposits                  1721 non-null   int32
#  8   Country                   1721 non-null   object
#  9   Area                      162 non-null    object
#  10  Region                    1721 non-null   category
#  11  Location Name             1720 non-null   object
#  12  Latitude                  1607 non-null   float64
#  13  Longitude                 1607 non-null   float64
#  14  Maximum Water Height (m)  1073 non-null   float64
#  15  Number of Runups          1721 non-null   int32
#  16  Tsunami Magnitude (Iida)  568 non-null    float64
#  17  Tsunami Intensity         797 non-null    float64
#  18  Deaths                    1721 non-null   int32
#  19  Death Description         225 non-null    category
#  20  Damage ($Mil)             41 non-null     float64
#  21  Damage Description        444 non-null    category
# dtypes: category(5), float64(8), int32(6), object(3)
# memory usage: 211.8+ KB

# %% [markdown]
# Next, we'll start looking at how to deal with our missing values.

# %%
df[['Earthquake Magnitude','Focal Depth (km)','Maximum Water Height (m)','Tsunami Magnitude (Iida)', 'Tsunami Intensity']].describe()
# Out:
#        Earthquake Magnitude  Focal Depth (km)  Maximum Water Height (m)  \
# count           1187.000000        877.000000               1073.000000
# mean               7.063858         33.627138                  4.766813
# std                0.773191         37.749340                 20.052475
# min                3.700000          0.000000                  0.010000
# 25%                6.600000         15.000000                  0.200000
# 50%                7.100000         29.000000                  1.000000
# 75%                7.600000         35.000000                  3.210000
# max                9.500000        600.000000                524.600000
#
#        Tsunami Magnitude (Iida)  Tsunami Intensity
# count                568.000000         797.000000
# mean                   0.484613           1.118871
# std                    2.210953           1.851267
# min                   -4.640000          -4.140000
# 25%                   -1.000000           0.000000
# 50%                    0.800000           1.000000
# 75%                    2.000000           2.500000
# max                    8.400000           9.000000

# %% [markdown]
# The missing values for columns containing data pertaining to measurements of the natural phenomena will be replaced with the median value of said columns. The median is preferred over the mean in this case as it is a robust estimate of location.

# %%
replace_with_median= [
    'Earthquake Magnitude',
    'Focal Depth (km)',
    'Maximum Water Height (m)',
    'Tsunami Magnitude (Iida)', 
    'Tsunami Intensity'
]

medians = df[replace_with_median].median()

df[replace_with_median] = df[replace_with_median].fillna(medians)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721 entries, 2 to 2392
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      1721 non-null   int32
#  1   Mo                        1721 non-null   int32
#  2   Dy                        1721 non-null   int32
#  3   Tsunami Event Validity    1721 non-null   category
#  4   Tsunami Cause Code        1721 non-null   category
#  5   Earthquake Magnitude      1721 non-null   float64
#  6   Focal Depth (km)          1721 non-null   float64
#  7   Deposits                  1721 non-null   int32
#  8   Country                   1721 non-null   object
#  9   Area                      162 non-null    object
#  10  Region                    1721 non-null   category
#  11  Location Name             1720 non-null   object
#  12  Latitude                  1607 non-null   float64
#  13  Longitude                 1607 non-null   float64
#  14  Maximum Water Height (m)  1721 non-null   float64
#  15  Number of Runups          1721 non-null   int32
#  16  Tsunami Magnitude (Iida)  1721 non-null   float64
#  17  Tsunami Intensity         1721 non-null   float64
#  18  Deaths                    1721 non-null   int32
#  19  Death Description         225 non-null    category
#  20  Damage ($Mil)             41 non-null     float64
#  21  Damage Description        444 non-null    category
# dtypes: category(5), float64(8), int32(6), object(3)
# memory usage: 211.8+ KB

# %% [markdown]
# Next will take a look at the missing values in the "Area" column

# %%
filtered_rows = df[df['Country'].isin(['USA','CANADA'])]

pd.set_option('display.max_rows', None)

print(filtered_rows[['Area', 'Country']])
# Out:
#      Area Country
# 124    AK     USA
# 125    AK     USA
# 173    CA     USA
# 197    CA     USA
# 225    AK     USA
# 232    WA     USA
# 333   NaN  CANADA
# 355    AK     USA
# 383    NL  CANADA
# 434    AK     USA
# 437    AK     USA
# 442    CA     USA
# 445    CA     USA
# 447    CA     USA
# 448    CA     USA
# 464    CA     USA
# 473    CA     USA
# 506    CA     USA
# 524   NaN     USA
# 540   NaN     USA
# 544    CA     USA
# 556    NL  CANADA
# 562    CA     USA
# 578    AK     USA
# 596    HI     USA
# 601    AK     USA
# 613    HI     USA
# 617    CA     USA
# 626    CA     USA
# 628    HI     USA
# 647    QC  CANADA
# 659    NY     USA
# 676    AK     USA
# 678    CA     USA
# 679    ME     USA
# 686    CA     USA
# 690    AK     USA
# 706    HI     USA
# 721    AK     USA
# 740    CA     USA
# 747    CA     USA
# 756    AK     USA
# 757    AK     USA
# 785    AK     USA
# 813    SC     USA
# 821    CA     USA
# 849    WA     USA
# 878    WA     USA
# 882    CA     USA
# 889    NJ     USA
# 904    AK     USA
# 926    AK     USA
# 927    AK     USA
# 938    AK     USA
# 943    CA     USA
# 972    AK     USA
# 977   NaN  CANADA
# 979    HI     USA
# 1000   AK     USA
# 1018   CA     USA
# 1022   CA     USA
# 1041   AK     USA
# 1050   QC  CANADA
# 1051   HI     USA
# 1091   NJ     USA
# 1096   CA     USA
# 1103   NS  CANADA
# 1136   AK     USA
# 1140   NS  CANADA
# 1164   HI     USA
# 1186   TX     USA
# 1227   AK     USA
# 1233   CA     USA
# 1238   ME     USA
# 1262   AK     USA
# 1263   AK     USA
# 1264   CA     USA
# 1268   BC  CANADA
# 1294   AK     USA
# 1296   BC  CANADA
# 1303   NL  CANADA
# 1313   CA     USA
# 1385   AK     USA
# 1414   AK     USA
# 1464   AK     USA
# 1465   BC  CANADA
# 1489   WA     USA
# 1490   WA     USA
# 1495   BC  CANADA
# 1518   HI     USA
# 1525   HI     USA
# 1579   AK     USA
# 1589   BC  CANADA
# 1592   AK     USA
# 1646   BC  CANADA
# 1656   AK     USA
# 1657   AK     USA
# 1661   NY     USA
# 1668   AK     USA
# 1673   AK     USA
# 1676   AK     USA
# 1736   AK     USA
# 1749   AK     USA
# 1761   AK     USA
# 1766   AK     USA
# 1788   BC  CANADA
# 1793   BC  CANADA
# 1798   HI     USA
# 1833   AK     USA
# 1899   AK     USA
# 1916   AK     USA
# 1918   AK     USA
# 1920   AK     USA
# 1929   HI     USA
# 1930   AK     USA
# 1931   CA     USA
# 1948   AK     USA
# 1955   CA     USA
# 1958   FL     USA
# 1972  NaN     USA
# 1982   CA     USA
# 1988   AK     USA
# 2017   AK     USA
# 2018   AK     USA
# 2059   BC  CANADA
# 2082   AK     USA
# 2089   BC  CANADA
# 2100   CA     USA
# 2103   BC  CANADA
# 2112   HI     USA
# 2127   AK     USA
# 2134   BC  CANADA
# 2143   AK     USA
# 2146  NaN     USA
# 2193   AK     USA
# 2201   AK     USA
# 2214   BC  CANADA
# 2218   AK     USA
# 2223  NaN     USA
# 2240   AK     USA
# 2246   AK     USA
# 2260   AK     USA
# 2262   AK     USA
# 2287   AK     USA
# 2304   AK     USA
# 2306   HI     USA
# 2308  NaN     USA
# 2323   OH     USA
# 2334   FL     USA
# 2337   FL     USA
# 2340   AK     USA
# 2341   AK     USA
# 2355   AK     USA
# 2387   AK     USA

# %% [markdown]
# The area column provides information on "the State, Province or Prefecture of the tsunami source" but it only does so for the US and Canada and enen then there are still some Nan values. We will fill these Nan values with "NA" for not applicable.

# %%
df['Area'].fillna('NA',inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721 entries, 2 to 2392
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      1721 non-null   int32
#  1   Mo                        1721 non-null   int32
#  2   Dy                        1721 non-null   int32
#  3   Tsunami Event Validity    1721 non-null   category
#  4   Tsunami Cause Code        1721 non-null   category
#  5   Earthquake Magnitude      1721 non-null   float64
#  6   Focal Depth (km)          1721 non-null   float64
#  7   Deposits                  1721 non-null   int32
#  8   Country                   1721 non-null   object
#  9   Area                      1721 non-null   object
#  10  Region                    1721 non-null   category
#  11  Location Name             1720 non-null   object
#  12  Latitude                  1607 non-null   float64
#  13  Longitude                 1607 non-null   float64
#  14  Maximum Water Height (m)  1721 non-null   float64
#  15  Number of Runups          1721 non-null   int32
#  16  Tsunami Magnitude (Iida)  1721 non-null   float64
#  17  Tsunami Intensity         1721 non-null   float64
#  18  Deaths                    1721 non-null   int32
#  19  Death Description         225 non-null    category
#  20  Damage ($Mil)             41 non-null     float64
#  21  Damage Description        444 non-null    category
# dtypes: category(5), float64(8), int32(6), object(3)
# memory usage: 211.8+ KB

# %% [markdown]
# Next, Location Name

# %%
df[df["Location Name"].isna()]
# Out:
#      Year  Mo  Dy Tsunami Event Validity Tsunami Cause Code  \
# 458  1855   2  11                    2.0                3.0
#
#      Earthquake Magnitude  Focal Depth (km)  Deposits      Country Area  \
# 458                   5.5              25.0         0  NEW ZEALAND   NA
#
#     Region Location Name  Latitude  Longitude  Maximum Water Height (m)  \
# 458   81.0           NaN     -39.2      177.6                       1.0
#
#      Number of Runups  Tsunami Magnitude (Iida)  Tsunami Intensity  Deaths  \
# 458                 1                       0.8                1.0       0
#
#     Death Description  Damage ($Mil) Damage Description
# 458               NaN            NaN                NaN

# %% [markdown]
# There is only one NaN value. Because we don't have the Location Name but we do have the Country information we will replace the missing value with "In New Zealand"

# %%
df["Location Name"].fillna("In New Zealand", inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721 entries, 2 to 2392
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      1721 non-null   int32
#  1   Mo                        1721 non-null   int32
#  2   Dy                        1721 non-null   int32
#  3   Tsunami Event Validity    1721 non-null   category
#  4   Tsunami Cause Code        1721 non-null   category
#  5   Earthquake Magnitude      1721 non-null   float64
#  6   Focal Depth (km)          1721 non-null   float64
#  7   Deposits                  1721 non-null   int32
#  8   Country                   1721 non-null   object
#  9   Area                      1721 non-null   object
#  10  Region                    1721 non-null   category
#  11  Location Name             1721 non-null   object
#  12  Latitude                  1607 non-null   float64
#  13  Longitude                 1607 non-null   float64
#  14  Maximum Water Height (m)  1721 non-null   float64
#  15  Number of Runups          1721 non-null   int32
#  16  Tsunami Magnitude (Iida)  1721 non-null   float64
#  17  Tsunami Intensity         1721 non-null   float64
#  18  Deaths                    1721 non-null   int32
#  19  Death Description         225 non-null    category
#  20  Damage ($Mil)             41 non-null     float64
#  21  Damage Description        444 non-null    category
# dtypes: category(5), float64(8), int32(6), object(3)
# memory usage: 211.8+ KB

# %% [markdown]
# The Damage ($Mil) column missing values will be replaced with 0. Here we make the assumption that if no data was collected, the damage value is less than 1 million USD.

# %%
df.loc[:, 'Damage ($Mil)'] = df['Damage ($Mil)'].fillna(0.00)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721 entries, 2 to 2392
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      1721 non-null   int32
#  1   Mo                        1721 non-null   int32
#  2   Dy                        1721 non-null   int32
#  3   Tsunami Event Validity    1721 non-null   category
#  4   Tsunami Cause Code        1721 non-null   category
#  5   Earthquake Magnitude      1721 non-null   float64
#  6   Focal Depth (km)          1721 non-null   float64
#  7   Deposits                  1721 non-null   int32
#  8   Country                   1721 non-null   object
#  9   Area                      1721 non-null   object
#  10  Region                    1721 non-null   category
#  11  Location Name             1721 non-null   object
#  12  Latitude                  1607 non-null   float64
#  13  Longitude                 1607 non-null   float64
#  14  Maximum Water Height (m)  1721 non-null   float64
#  15  Number of Runups          1721 non-null   int32
#  16  Tsunami Magnitude (Iida)  1721 non-null   float64
#  17  Tsunami Intensity         1721 non-null   float64
#  18  Deaths                    1721 non-null   int32
#  19  Death Description         225 non-null    category
#  20  Damage ($Mil)             1721 non-null   float64
#  21  Damage Description        444 non-null    category
# dtypes: category(5), float64(8), int32(6), object(3)
# memory usage: 211.8+ KB

# %%
df[['Death Description','Damage Description']].describe()
# Out:
#         Death Description  Damage Description
# count               225.0               444.0
# unique                4.0                 4.0
# top                   1.0                 1.0
# freq                121.0               258.0

# %% [markdown]
# The death and damage description missing values will be replaced with 1 as this includes very small quantaties like "Few (~1 to 50 deaths)" and "LIMITED (roughly corresponding to less than $1 million)"

# %%
df.loc[:, ['Death Description','Damage Description']] = df[['Death Description','Damage Description']].fillna(1)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721 entries, 2 to 2392
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      1721 non-null   int32
#  1   Mo                        1721 non-null   int32
#  2   Dy                        1721 non-null   int32
#  3   Tsunami Event Validity    1721 non-null   category
#  4   Tsunami Cause Code        1721 non-null   category
#  5   Earthquake Magnitude      1721 non-null   float64
#  6   Focal Depth (km)          1721 non-null   float64
#  7   Deposits                  1721 non-null   int32
#  8   Country                   1721 non-null   object
#  9   Area                      1721 non-null   object
#  10  Region                    1721 non-null   category
#  11  Location Name             1721 non-null   object
#  12  Latitude                  1607 non-null   float64
#  13  Longitude                 1607 non-null   float64
#  14  Maximum Water Height (m)  1721 non-null   float64
#  15  Number of Runups          1721 non-null   int32
#  16  Tsunami Magnitude (Iida)  1721 non-null   float64
#  17  Tsunami Intensity         1721 non-null   float64
#  18  Deaths                    1721 non-null   int32
#  19  Death Description         1721 non-null   category
#  20  Damage ($Mil)             1721 non-null   float64
#  21  Damage Description        1721 non-null   category
# dtypes: category(5), float64(8), int32(6), object(3)
# memory usage: 211.8+ KB

# %% [markdown]
# Let's take a look at our data frame.

# %%
df.head()
# Out:
#     Year  Mo  Dy Tsunami Event Validity Tsunami Cause Code  \
# 2   1750  12  17                    2.0                1.0
# 5   1751   5  20                    4.0                3.0
# 6   1751   5  25                    4.0                1.0
# 10  1751  10  18                    3.0                1.0
# 12  1751  11  21                    2.0                1.0
#
#     Earthquake Magnitude  Focal Depth (km)  Deposits             Country Area  \
# 2                    7.1              29.0         0             CROATIA   NA
# 5                    6.6              29.0         0               JAPAN   NA
# 6                    8.5              29.0         1               CHILE   NA
# 10                   7.3              29.0         0  DOMINICAN REPUBLIC   NA
# 12                   7.1              29.0         0               ITALY   NA
#
#    Region        Location Name  Latitude  Longitude  Maximum Water Height (m)  \
# 2    50.0               RIJEKA      46.0      12.25                       1.0
# 5    85.0    NW. HONSHU ISLAND      37.2     138.10                       1.0
# 6    89.0        CENTRAL CHILE     -37.0     -73.00                       3.5
# 10   74.0  AZUA  DE COMPOSTELA      18.5     -70.70                       1.0
# 12   50.0         LIGURIAN SEA      43.8       9.00                       1.0
#
#     Number of Runups  Tsunami Magnitude (Iida)  Tsunami Intensity  Deaths  \
# 2                  1                       0.8                3.0       0
# 5                  1                       1.0                1.0    2100
# 6                  7                       1.8                3.5      65
# 10                 3                       0.8                1.0       0
# 12                 1                       0.8                3.0       0
#
#    Death Description  Damage ($Mil) Damage Description
# 2                1.0            0.0                1.0
# 5                4.0            0.0                4.0
# 6                2.0            0.0                1.0
# 10               1.0            0.0                3.0
# 12               1.0            0.0                1.0

# %% [markdown]
# We can see that our index is off. Let's reset it.

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    Year  Mo  Dy Tsunami Event Validity Tsunami Cause Code  \
# 0  1750  12  17                    2.0                1.0
# 1  1751   5  20                    4.0                3.0
# 2  1751   5  25                    4.0                1.0
# 3  1751  10  18                    3.0                1.0
# 4  1751  11  21                    2.0                1.0
#
#    Earthquake Magnitude  Focal Depth (km)  Deposits             Country Area  \
# 0                   7.1              29.0         0             CROATIA   NA
# 1                   6.6              29.0         0               JAPAN   NA
# 2                   8.5              29.0         1               CHILE   NA
# 3                   7.3              29.0         0  DOMINICAN REPUBLIC   NA
# 4                   7.1              29.0         0               ITALY   NA
#
#   Region        Location Name  Latitude  Longitude  Maximum Water Height (m)  \
# 0   50.0               RIJEKA      46.0      12.25                       1.0
# 1   85.0    NW. HONSHU ISLAND      37.2     138.10                       1.0
# 2   89.0        CENTRAL CHILE     -37.0     -73.00                       3.5
# 3   74.0  AZUA  DE COMPOSTELA      18.5     -70.70                       1.0
# 4   50.0         LIGURIAN SEA      43.8       9.00                       1.0
#
#    Number of Runups  Tsunami Magnitude (Iida)  Tsunami Intensity  Deaths  \
# 0                 1                       0.8                3.0       0
# 1                 1                       1.0                1.0    2100
# 2                 7                       1.8                3.5      65
# 3                 3                       0.8                1.0       0
# 4                 1                       0.8                3.0       0
#
#   Death Description  Damage ($Mil) Damage Description
# 0               1.0            0.0                1.0
# 1               4.0            0.0                4.0
# 2               2.0            0.0                1.0
# 3               1.0            0.0                3.0
# 4               1.0            0.0                1.0

# %%
df.tail()
# Out:
#       Year  Mo  Dy Tsunami Event Validity Tsunami Cause Code  \
# 1716  2023  10   5                    4.0                1.0
# 1717  2023  10   8                    4.0                0.0
# 1718  2023  11  22                    4.0                1.0
# 1719  2023  12   2                    4.0                1.0
# 1720  2023  12   7                    4.0                1.0
#
#       Earthquake Magnitude  Focal Depth (km)  Deposits      Country Area  \
# 1716                   6.1              10.0         0        JAPAN   NA
# 1717                   7.1              29.0         0        JAPAN   NA
# 1718                   6.7              22.0         0      VANUATU   NA
# 1719                   7.6              32.0         0  PHILIPPINES   NA
# 1720                   7.1              48.0         0      VANUATU   NA
#
#      Region       Location Name  Latitude  Longitude  \
# 1716   85.0  IZU ISLANDS, JAPAN    29.940    139.950
# 1717   85.0  IZU ISLANDS, JAPAN    29.700    139.900
# 1718   82.0     VANUATU ISLANDS   -14.985    167.983
# 1719   84.0  E. MINDANAO ISLAND     8.527    126.449
# 1720   82.0     VANUATU ISLANDS   -20.659    169.206
#
#       Maximum Water Height (m)  Number of Runups  Tsunami Magnitude (Iida)  \
# 1716                      0.30                 1                       0.8
# 1717                      0.30                12                       0.8
# 1718                      0.06                 1                       0.8
# 1719                      0.32                29                       0.8
# 1720                      0.08                 3                       0.8
#
#       Tsunami Intensity  Deaths Death Description  Damage ($Mil)  \
# 1716                1.0       0               1.0            0.0
# 1717                1.0       0               1.0            0.0
# 1718                1.0       0               1.0            0.0
# 1719                1.0       0               1.0            0.0
# 1720                1.0       0               1.0            0.0
#
#      Damage Description
# 1716                1.0
# 1717                1.0
# 1718                1.0
# 1719                1.0
# 1720                1.0

# %% [markdown]
# Let's do a deeper exploration of our data

# %%
df.describe(include='all').T
# Out:
#                            count unique             top    freq         mean  \
# Year                      1721.0    NaN             NaN     NaN  1928.017432
# Mo                        1721.0    NaN             NaN     NaN     6.463103
# Dy                        1721.0    NaN             NaN     NaN    14.974433
# Tsunami Event Validity    1721.0    3.0             4.0   894.0          NaN
# Tsunami Cause Code        1721.0   11.0             1.0  1304.0          NaN
# Earthquake Magnitude      1721.0    NaN             NaN     NaN     7.075073
# Focal Depth (km)          1721.0    NaN             NaN     NaN    31.357931
# Deposits                  1721.0    NaN             NaN     NaN     0.345729
# Country                     1721     95           JAPAN     229          NaN
# Area                        1721     20              NA    1559          NaN
# Region                    1721.0   22.0            50.0   247.0          NaN
# Location Name               1721    630  NORTHERN CHILE      51          NaN
# Latitude                  1607.0    NaN             NaN     NaN    14.810466
# Longitude                 1607.0    NaN             NaN     NaN    42.488318
# Maximum Water Height (m)  1721.0    NaN             NaN     NaN     3.348512
# Number of Runups          1721.0    NaN             NaN     NaN    17.255665
# Tsunami Magnitude (Iida)  1721.0    NaN             NaN     NaN     0.695909
# Tsunami Intensity         1721.0    NaN             NaN     NaN     1.055049
# Deaths                    1721.0    NaN             NaN     NaN    303.83498
# Death Description         1721.0    4.0             1.0  1617.0          NaN
# Damage ($Mil)             1721.0    NaN             NaN     NaN   154.498078
# Damage Description        1721.0    4.0             1.0  1535.0          NaN
#
#                                   std      min     25%     50%      75%  \
# Year                        68.825527   1750.0  1876.0  1936.0   1988.0
# Mo                           3.495172      0.0     3.0     7.0      9.0
# Dy                           8.862413      0.0     8.0    15.0     22.0
# Tsunami Event Validity            NaN      NaN     NaN     NaN      NaN
# Tsunami Cause Code                NaN      NaN     NaN     NaN      NaN
# Earthquake Magnitude         0.642262      3.7     6.9     7.1      7.3
# Focal Depth (km)            27.039157      0.0    28.0    29.0     30.0
# Deposits                     3.886118      0.0     0.0     0.0      0.0
# Country                           NaN      NaN     NaN     NaN      NaN
# Area                              NaN      NaN     NaN     NaN      NaN
# Region                            NaN      NaN     NaN     NaN      NaN
# Location Name                     NaN      NaN     NaN     NaN      NaN
# Latitude                    28.467834  -62.877 -7.0645    17.2   38.516
# Longitude                  110.314905 -179.971 -70.375    94.0  141.701
# Maximum Water Height (m)    15.935655     0.01     0.5     1.0      1.5
# Number of Runups           169.098295      0.0     1.0     2.0      5.0
# Tsunami Magnitude (Iida)     1.278063    -4.64     0.8     0.8      0.8
# Tsunami Intensity            1.260788    -4.14     1.0     1.0      1.0
# Deaths                    5877.505437      0.0     0.0     0.0      0.0
# Death Description                 NaN      NaN     NaN     NaN      NaN
# Damage ($Mil)             5360.524863      0.0     0.0     0.0      0.0
# Damage Description                NaN      NaN     NaN     NaN      NaN
#
#                                max
# Year                        2023.0
# Mo                            12.0
# Dy                            31.0
# Tsunami Event Validity         NaN
# Tsunami Cause Code             NaN
# Earthquake Magnitude           9.5
# Focal Depth (km)             600.0
# Deposits                     146.0
# Country                        NaN
# Area                           NaN
# Region                         NaN
# Location Name                  NaN
# Latitude                     78.37
# Longitude                  179.984
# Maximum Water Height (m)     524.6
# Number of Runups            6317.0
# Tsunami Magnitude (Iida)       8.4
# Tsunami Intensity              9.0
# Deaths                    227899.0
# Death Description              NaN
# Damage ($Mil)             220136.6
# Damage Description             NaN

# %% [markdown]
# Temporal Distribution:
# Year: The data spans from 1750 to 2023, with most events occurring around 1928, showing a historical range of over 270 years. The standard deviation of 68.83 years indicates a broad temporal spread of events.
# Month (Mo): The average month is around June (6.46), but the data spans all months. This suggests no specific monthly trend in the occurrence of these events.
# Day (Dy): The average day is mid-month (about the 15th), with complete coverage of all days in a month.
#
#
# Seismic Data:
# Earthquake Magnitude: Ranges from 3.7 to 9.5 with an average of around 7.07, indicating that the dataset includes moderate to extremely strong earthquakes.
# Focal Depth (km): Varies widely from 0 to 600 km, with most events having a focal depth around 28 to 31 km, indicative of shallow to intermediate depth earthquakes.
#
#
# Country:
# The dataset includes events from 95 countries, with Japan being the most common location.
# Area: Has 20 unique values, but 'NA' is most frequent.
# Location Name: Shows a high degree of variability with 630 unique locations.
#
#
# Latitude and Longitude:
# Cover a wide range of values, indicating a global spread of tsunami events. Still have missing values.
#
# Impact Measures:
# Maximum Water Height (m): Varies significantly, up to 524.6 meters, pointing to the varying intensities of tsunami waves.
# Number of Runups: Has a wide range, suggesting diverse impacts on different shorelines.
# Deaths: The number of deaths varies widely, with some events causing up to 227,899 deaths, underscoring the potentially catastrophic nature of these events.
# Damage ($Mil): Economic impacts also vary greatly, with some events causing up to $220,136.6 million in damages.

# %% [markdown]
# Not satisfied with the missing values in longitude and latitude. They will be filled with the mean of other entries with the same location name.

# %%
df['Latitude'] = df.groupby('Location Name')['Latitude'].transform(lambda x: x.fillna(x.mean()))
df['Longitude'] = df.groupby('Location Name')['Longitude'].transform(lambda x: x.fillna(x.mean()))


missing_locations = df[df['Latitude'].isnull() | df['Longitude'].isnull()]['Location Name'].unique()
print("Location names with missing latitude or longitude:", missing_locations)
# Out:
# Location names with missing latitude or longitude: ['LATAKIA' 'GERMANY & DENMARK' 'AWA, BOSO, JAPAN' 'BAY OF NAPLES'
#  'DUBROVNIK' 'ST. LAWRENCE' 'IZMIR' 'ISMIR' 'NAPLES' 'KHALKI ISLET'
#  'LIVORNO - LIGURIAN SEA' 'TYRRHENIAN SEA -SALERNO' 'LIGURIAN SEA  - NICE'
#  'HALF MOON BAY, N. CALIFORNIA' 'GULF OF GENOVA' 'CALLAO' 'LIXOURI'
#  'SAN FRANCISCO, N. CALIFORNIA' 'SAMOA' 'MALO PASS' 'SANTO DOMINGO'
#  'MAUPIHAA' 'GULF OF MEXICO' 'CALIFORNIA' 'BONDI BEACH, SYDNEY'
#  'SOUTH AFRICA' 'EASTERN ITALY, ADRIATIC SEA' 'NAGASAKI, JAPAN'
#  'DAYTONA BEACH, FL' 'YELLOW SEA' 'E. CHINA SEA-S.JAPAN'
#  'CHEJU (JEJU) STRAIT' 'NORTHWEST ATLANTIC OCEAN'
#  'MEDITERRANEAN AND BLACK SEAS' 'NORTH SEA' 'NORTHEAST U.S.A.'
#  'BALEARIC ISLANDS' 'LAKE ERIE']

# %% [markdown]
# Seems we still have missing values and it's due to having no data on latitude and longitude for certain locations. They will instead be filled with latitude and longitude info of entries with the same country. Any left will be filled with the median.

# %%
df['Latitude'] = df.groupby('Country')['Latitude'].transform(lambda x: x.fillna(x.mean()))
df['Longitude'] = df.groupby('Country')['Longitude'].transform(lambda x: x.fillna(x.mean()))

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1721 entries, 0 to 1720
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      1721 non-null   int32
#  1   Mo                        1721 non-null   int32
#  2   Dy                        1721 non-null   int32
#  3   Tsunami Event Validity    1721 non-null   category
#  4   Tsunami Cause Code        1721 non-null   category
#  5   Earthquake Magnitude      1721 non-null   float64
#  6   Focal Depth (km)          1721 non-null   float64
#  7   Deposits                  1721 non-null   int32
#  8   Country                   1721 non-null   object
#  9   Area                      1721 non-null   object
#  10  Region                    1721 non-null   category
#  11  Location Name             1721 non-null   object
#  12  Latitude                  1712 non-null   float64
#  13  Longitude                 1712 non-null   float64
#  14  Maximum Water Height (m)  1721 non-null   float64
#  15  Number of Runups          1721 non-null   int32
#  16  Tsunami Magnitude (Iida)  1721 non-null   float64
#  17  Tsunami Intensity         1721 non-null   float64
#  18  Deaths                    1721 non-null   int32
#  19  Death Description         1721 non-null   category
#  20  Damage ($Mil)             1721 non-null   float64
#  21  Damage Description        1721 non-null   category
# dtypes: category(5), float64(8), int32(6), object(3)
# memory usage: 198.5+ KB

# %%
median_latitude = df['Latitude'].median()
median_longitude = df['Longitude'].median()

df['Latitude'].fillna(median_latitude, inplace=True)
df['Longitude'].fillna(median_longitude, inplace=True)

# %% [markdown]
# We now have only the data we need with no missing values other than the longitude and latitude and the correct data types. Let's export to csv

# %%
df.to_csv('CleanedTsunamiDataIndex', index=True)

# %% [markdown]
# We now have an improved data set with no missing values. Lets separate our columns into numerical and categorical columns

# %%
cat_cols=df.select_dtypes(include=['object', 'category']).columns
num_cols = df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Tsunami Event Validity', 'Tsunami Cause Code', 'Country', 'Area',
#        'Region', 'Location Name', 'Death Description', 'Damage Description'],
#       dtype='object')
# Numerical Variables:
# ['Year', 'Mo', 'Dy', 'Earthquake Magnitude', 'Focal Depth (km)', 'Deposits', 'Latitude', 'Longitude', 'Maximum Water Height (m)', 'Number of Runups', 'Tsunami Magnitude (Iida)', 'Tsunami Intensity', 'Deaths', 'Damage ($Mil)']

# %% [markdown]
# Univariate analysis using Histogram and  Box Plot for numerical variables.

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(df[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.show()
# Out:
# Year
# Skew : -0.52
# Mo
# Skew : -0.07
# Dy
# Skew : 0.01
# Earthquake Magnitude
# Skew : -0.74
# Focal Depth (km)
# Skew : 12.28
# Deposits
# Skew : 31.68
# Latitude
# Skew : -0.4
# Longitude
# Skew : -0.41
# Maximum Water Height (m)
# Skew : 22.7
# Number of Runups
# Skew : 31.3
# Tsunami Magnitude (Iida)
# Skew : -0.32
# Tsunami Intensity
# Skew : -0.34
# Deaths
# Skew : 34.58
# Damage ($Mil)
# Skew : 40.33

# %% [markdown]
# Insights
# -We can see that the years span from 1750 to 2023 and it seams as though the rate of events is increasing. It will be interesting to take a closer lok at that
# -The earthquake magnitude seams to be centered around 7 which is reasonable given that the data is only for earthquakes having caused a tsunami
# -Focal depth and deposits seem to have significant outliers on the upper bounds
# -The latitude and longitude plots seam to indicate a slight concentration in the northern and eastern hemispheres
# -Max water height is mostly concentrate with the 0 to 50 meter range with some significant outliers reaching 500
# -Number of run-ups is mostly concentrated around 0-500 with some extreme outliers
# -The peculiarly large concentration around the median for magnitude and intensity is likely due to the way we have filled missing values for these columns using the median
# -Most events deaths seem to be well bellow 10000 and there is an extreme outlier nearing 250000
# -Damage cost are  mostly close to 0 and we have one particular extreme outlier.

# %%
N = 5  

# We Iterate through each categorical column
for col in cat_cols:
    
    top_categories = df[col].value_counts().nlargest(N).index
    
   
    fig, ax = plt.subplots(figsize=(8, 6))
    plt.title(f'Top {N} categories for {col}')
    sns.countplot(x=col, data=df[df[col].isin(top_categories)], color='blue', order=top_categories)

   
    total_entries = len(df[col])
    for p in ax.patches:
        percentage = f'{100 * p.get_height() / total_entries:.1f}%'
        ax.annotate(percentage, (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %% [markdown]
# Insights
# -Over 70% of eventas have a validity code of 3 or 4. 3 being probable tsunami 4 being definite tsunami
# -75% of events in the data set have a cause code of 1 which mean the tsunami was caused by an earthquake
# -Over 40% of events in our data set occured in the top 5 countries Japan, Indonesia, USA, Chile, and Greece. Japan being number one with 13.3%

# %% [markdown]
# Multivariate analysis

# %%
numerical_columns = df.select_dtypes(include='number') 

correlation_matrix = numerical_columns.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix for Numerical Columns')
plt.show()

# %% [markdown]
# Insights
#
# Number of Runups' is highly correlated with 'Tsunami Intensity' (0.91), suggesting that as the number of waves reaching the shore increases, so does the intensity of the tsunami.
#
# 'Deaths' are strongly correlated with 'Maximum Water Height (m)' (0.92), which is intuitive as higher tsunami waves can be more destructive and lead to higher death tolls.
#
# Similarly, 'Deaths' show a strong correlation with 'Damage ($Mil)' (0.91), indicating that more severe tsunamis that cause higher fatalities also tend to result in more monetary damage.
#
# The strong correlation between 'Maximum Water Height (m)' and 'Damage ($Mil)' (0.91) reinforces the understanding that taller tsunami waves are likely to cause more damage.
#
# 'Tsunami Magnitude (Iida)' and 'Tsunami Intensity' have a significant positive correlation (0.56), which might be expected since both metrics are related to the strength of the tsunami. However, the correlation is not as strong as one might anticipate, suggesting that there are other factors at play determining the perceived intensity of a tsunami beyond its magnitude.
#
# The lack of strong correlations between 'Latitude' and 'Longitude' with other variables could indicate that the impact of a tsunami is not strongly dependent on the location of occurrence within the dataset's geographical scope.
#
# The low correlations between 'Earthquake Magnitude' and both 'Tsunami Magnitude (Iida)' and 'Tsunami Intensity' suggest that while earthquakes can cause tsunamis, the strength of the earthquake does not linearly translate to the strength or intensity of the tsunami. This may be due to a variety of factors including depth of the earthquake, distance from the shore, and local topography.
#
# Time variables ('Year', 'Mo', 'Dy') do not show a significant correlation with tsunami metrics, indicating that the timing of a tsunami does not predict its magnitude, intensity, or impact.

# %% [markdown]
# We will continue with data visualization in Tableau
